# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("train_F3fUq2S (1).csv")

# %%
data
# Out:
#       campaign_id  sender  subject_len  body_len  mean_paragraph_len  \
# 0               1       3           76     10439                  39
# 1               2       3           54      2570                 256
# 2               3       3           59     12801                  16
# 3               4       3           74     11037                  30
# 4               5       3           80     10011                  27
# ...           ...     ...          ...       ...                 ...
# 1883         1884       3           88      1451                  75
# 1884         1885       3           58     10537                  40
# 1885         1886       3           89     11050                  26
# 1886         1887       3           58     10537                  40
# 1887         1888       3           89     11050                  26
#
#       day_of_week  is_weekend times_of_day  category  Product  ...  is_image  \
# ...

# %%
plt.scatter(data.click_rate,data.sender)

# %%
corr=data.corr()

# %%
corr.click_rate
# Out:
# campaign_id           0.053315
# sender               -0.031398
# subject_len          -0.180143
# body_len             -0.247866
# mean_paragraph_len    0.178042
# day_of_week           0.086372
# is_weekend            0.114138
# category             -0.167756
# Product               0.121602
# no_of_CTA            -0.172637
# mean_CTA_len         -0.031162
# is_image             -0.021527
# is_personalised       0.032922
# is_quote             -0.098402
# is_timer                   NaN
# is_emoticons         -0.094305
# is_discount          -0.086105
# is_price             -0.030540
# is_urgency           -0.114284
# target_audience       0.038713
# click_rate            1.000000
# Name: click_rate, dtype: float64

# %%
data.drop(["is_timer",'campaign_id'],axis=1)
# Out:
#       sender  subject_len  body_len  mean_paragraph_len  day_of_week  \
# 0          3           76     10439                  39            5
# 1          3           54      2570                 256            5
# 2          3           59     12801                  16            5
# 3          3           74     11037                  30            4
# 4          3           80     10011                  27            5
# ...      ...          ...       ...                 ...          ...
# 1883       3           88      1451                  75            2
# 1884       3           58     10537                  40            2
# 1885       3           89     11050                  26            1
# 1886       3           58     10537                  40            1
# 1887       3           89     11050                  26            0
#
#       is_weekend times_of_day  category  Product  no_of_CTA  mean_CTA_len  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dummie=pd.get_dummies(data.times_of_day)

# %%
dummie
# Out:
#       Evening  Morning  Noon
# 0           0        0     1
# 1           0        1     0
# 2           0        0     1
# 3           1        0     0
# 4           0        0     1
# ...       ...      ...   ...
# 1883        0        0     1
# 1884        1        0     0
# 1885        1        0     0
# 1886        1        0     0
# 1887        1        0     0
#
# [1888 rows x 3 columns]

# %%
data=data.drop(["times_of_day"],axis=1)

# %%
data=pd.concat([data,dummie],axis=1)

# %%
data
# Out:
#       campaign_id  sender  subject_len  body_len  mean_paragraph_len  \
# 0               1       3           76     10439                  39
# 1               2       3           54      2570                 256
# 2               3       3           59     12801                  16
# 3               4       3           74     11037                  30
# 4               5       3           80     10011                  27
# ...           ...     ...          ...       ...                 ...
# 1883         1884       3           88      1451                  75
# 1884         1885       3           58     10537                  40
# 1885         1886       3           89     11050                  26
# 1886         1887       3           58     10537                  40
# 1887         1888       3           89     11050                  26
#
#       day_of_week  is_weekend  category  Product  no_of_CTA  ...  is_timer  \
# ...

# %%
for x in range( len(data.mean_paragraph_len)):
     dummie["noofparagraph"][x]=(data.mean_paragraph_len[x]/data.body_len[x])
# Out:
# <ipython-input-46-c26b47e8af5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dummie["noofparagraph"][x]=(data.mean_paragraph_len[x]/data.body_len[x])

# %%
dummie
# Out:
#       Evening  Morning  Noon  noofparagraphs  noofparagraph
# 0           0        0     1        0.002353       0.003736
# 1           0        1     0        0.002353       0.099611
# 2           0        0     1        0.002353       0.001250
# 3           1        0     0        0.002353       0.002718
# 4           0        0     1        0.002353       0.002697
# ...       ...      ...   ...             ...            ...
# 1883        0        0     1        0.002353       0.051688
# 1884        1        0     0        0.002353       0.003796
# 1885        1        0     0        0.002353       0.002353
# 1886        1        0     0        0.002353       0.003796
# 1887        1        0     0        0.002353       0.002353
#
# [1888 rows x 5 columns]

# %%
data['noofparagraph']=dummie.noofparagraph

# %%
from lightgbm import LGBMRegressor
lbgmr=LGBMRegressor()

# %%
x=data.drop("click_rate",axis=1)
y=data.click_rate

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
model_lbgmr=lbgmr.fit(X_train,y_train)

# %%
model_lbgmr.score(X_train,y_train)
# Out:
# 0.8502431339756945

# %%
ypred=model_lbgmr.predict(X_test)

# %%
model_lbgmr.score(X_test,y_test)
# Out:
# 0.496153814703549
